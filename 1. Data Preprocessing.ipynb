# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
import os, shutil

# 원본 데이터셋을 압축 해제한 디렉터리 경로
original_bart_simpson = './simpsons_data/bart_simpson'
original_homer_simpson = './simpsons_data/homer_simpson'
original_lisa_simpson = './simpsons_data/lisa_simpson'
original_marge_simpson = './simpsons_data/marge_simpson'

# 소규모 데이터셋을 저장할 디렉터리
base_dir = './simpsons_small'
if os.path.exists(base_dir):  # 반복적인 실행을 위해 디렉토리를 삭제합니다.
    shutil.rmtree(base_dir)   # 이 코드는 책에 포함되어 있지 않습니다.
os.mkdir(base_dir)    
    
# 훈련, 검증, 테스트 분할을 위한 디렉터리
train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

# 원본 데이터셋 파일 이름
fnames_train = ['pic_%04d.jpg'%(i) for i in range(1000)]
fnames_validation = ['pic_%04d.jpg'%(i) for i in range(1000, 1200)]
fnames_test = ['pic_%04d.jpg'%(i) for i in range(1200, 1250)]

### Bart ---------------------------------------------------------###
# 훈련용 Bart 사진 디렉터리
train_bart_dir = os.path.join(train_dir, 'bart_simpson')
os.mkdir(train_bart_dir)
# 검증용 Bart 사진 디렉터리
validation_bart_dir = os.path.join(validation_dir, 'bart_simpson')
os.mkdir(validation_bart_dir)
# 테스트용 Bart 사진 디렉터리
test_bart_dir = os.path.join(test_dir, 'bart_simpson')
os.mkdir(test_bart_dir)

# 처음 1,000개의 Bart 이미지를 train_bart_dir에 복사합니다
bart_num = 0;
for fname in fnames_train:
    src = os.path.join(original_bart_simpson, fname)
    dst = os.path.join(train_bart_dir,'bart%04d.jpg'%(bart_num))
    shutil.copyfile(src,dst)
    bart_num += 1
# 다음 200개 Bart 이미지를 validation_bart_dir에 복사합니다
bart_num = 0;
for fname in fnames_validation:
    src = os.path.join(original_bart_simpson, fname)
    dst = os.path.join(validation_bart_dir, 'bart%04d.jpg'%(bart_num))
    shutil.copyfile(src, dst)
    bart_num += 1
# 다음 50개 Bart 이미지를 test_bart_dir에 복사합니다
bart_num = 0;
for fname in fnames_test:
    src = os.path.join(original_bart_simpson, fname)
    dst = os.path.join(test_bart_dir, 'bart%04d.jpg'%(bart_num))
    shutil.copyfile(src, dst)
    bart_num += 1

### --------------------------------------------------------------###

### Homer ---------------------------------------------------------###
# 훈련용 Homer 사진 디렉터리
train_homer_dir = os.path.join(train_dir, 'homer_simpson')
os.mkdir(train_homer_dir)
# 검증용 Homer 사진 디렉터리
validation_homer_dir = os.path.join(validation_dir, 'homer_simpson')
os.mkdir(validation_homer_dir)
# 테스트용 homer 사진 디렉터리
test_homer_dir = os.path.join(test_dir, 'homer_simpson')
os.mkdir(test_homer_dir)

# 처음 1,000개의 homer 이미지를 train_homer_dir에 복사합니다
homer_num = 0;
for fname in fnames_train:
    src = os.path.join(original_homer_simpson, fname)
    dst = os.path.join(train_homer_dir,'homer%04d.jpg'%(homer_num))
    shutil.copyfile(src,dst)
    homer_num += 1
# 다음 200개 homer 이미지를 validation_homer_dir에 복사합니다
homer_num = 0;
for fname in fnames_validation:
    src = os.path.join(original_homer_simpson, fname)
    dst = os.path.join(validation_homer_dir, 'homer%04d.jpg'%(homer_num))
    shutil.copyfile(src, dst)
    homer_num += 1
# 다음 50개 Bart 이미지를 test_homer_dir에 복사합니다
homer_num = 0;
for fname in fnames_test:
    src = os.path.join(original_homer_simpson, fname)
    dst = os.path.join(test_homer_dir, 'homer%04d.jpg'%(homer_num))
    shutil.copyfile(src, dst)
    homer_num += 1
### --------------------------------------------------------------### 

### Lisa ---------------------------------------------------------###
# 훈련용 lisa 사진 디렉터리
train_lisa_dir = os.path.join(train_dir, 'lisa_simpson')
os.mkdir(train_lisa_dir)
# 검증용 lisa 사진 디렉터리
validation_lisa_dir = os.path.join(validation_dir, 'lisa_simpson')
os.mkdir(validation_lisa_dir)
# 테스트용 lisa 사진 디렉터리
test_lisa_dir = os.path.join(test_dir, 'lisa_simpson')
os.mkdir(test_lisa_dir)

# 처음 1,000개의 lisa 이미지를 train_lisa_dir에 복사합니다
lisa_num = 0;
for fname in fnames_train:
    src = os.path.join(original_lisa_simpson, fname)
    dst = os.path.join(train_lisa_dir,'lisa%04d.jpg'%(lisa_num))
    shutil.copyfile(src,dst)
    lisa_num += 1
# 다음 200개 lisa 이미지를 validation_lisa_dir에 복사합니다
lisa_num = 0;
for fname in fnames_validation:
    src = os.path.join(original_lisa_simpson, fname)
    dst = os.path.join(validation_lisa_dir, 'lisa%04d.jpg'%(lisa_num))
    shutil.copyfile(src, dst)
    lisa_num += 1
# 다음 50개 Bart 이미지를 test_lisa_dir에 복사합니다
lisa_num = 0;
for fname in fnames_test:
    src = os.path.join(original_lisa_simpson, fname)
    dst = os.path.join(test_lisa_dir, 'lisa%04d.jpg'%(lisa_num))
    shutil.copyfile(src, dst)
    lisa_num += 1
### --------------------------------------------------------------###

### Marge ---------------------------------------------------------###
# 훈련용 marge 사진 디렉터리
train_marge_dir = os.path.join(train_dir, 'marge_simpson')
os.mkdir(train_marge_dir)
# 검증용 marge 사진 디렉터리
validation_marge_dir = os.path.join(validation_dir, 'marge_simpson')
os.mkdir(validation_marge_dir)
# 테스트용 marge 사진 디렉터리
test_marge_dir = os.path.join(test_dir, 'marge_simpson')
os.mkdir(test_marge_dir)

# 처음 1,000개의 marge 이미지를 train_marge_dir에 복사합니다
marge_num = 0;
for fname in fnames_train:
    src = os.path.join(original_marge_simpson, fname)
    dst = os.path.join(train_marge_dir,'marge%04d.jpg'%(marge_num))
    shutil.copyfile(src,dst)
    marge_num += 1
# 다음 200개 marge 이미지를 validation_marge_dir에 복사합니다
marge_num = 0;
for fname in fnames_validation:
    src = os.path.join(original_marge_simpson, fname)
    dst = os.path.join(validation_marge_dir, 'marge%04d.jpg'%(marge_num))
    shutil.copyfile(src, dst)
    marge_num += 1
# 다음 50개 Bart 이미지를 test_marge_dir에 복사합니다
marge_num = 0;
for fname in fnames_test:
    src = os.path.join(original_marge_simpson, fname)
    dst = os.path.join(test_marge_dir, 'marge%04d.jpg'%(marge_num))
    shutil.copyfile(src, dst)
    marge_num += 1
### --------------------------------------------------------------###

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\keras\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
from keras import optimizers

model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %%
from keras.preprocessing.image import ImageDataGenerator

# 모든 이미지를 1/255로 스케일을 조정합니다
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # 타깃 디렉터리
        train_dir,
        # 모든 이미지를 150 × 150 크기로 바꿉니다
        target_size=(150, 150),
        batch_size=20,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='categorical')
# Out:
# Found 4000 images belonging to 4 classes.
# Found 4000 images belonging to 4 classes.

# %%
# import pillow
for data_batch, labels_batch in train_generator:
    print('배치 데이터 크기:', data_batch.shape)
    print('배치 레이블 크기:', labels_batch.shape)
    break
# Out:
# 배치 데이터 크기: (20, 150, 150, 3)
# 배치 레이블 크기: (20, 4)

# %%
for i,j in train_generator:
#     print(i)
    print(j[3])
    break
# Out:
# [1. 0. 0. 0.]

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=10,
      epochs=100,
      validation_data=validation_generator,
      validation_steps=5)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.8633 - acc: 0.5550 - val_loss: 0.8258 - val_acc: 0.6300
# Epoch 2/100
# 10/10 [==============================] - 1s 56ms/step - loss: 0.7965 - acc: 0.6550 - val_loss: 0.9525 - val_acc: 0.5700
# Epoch 3/100
# 10/10 [==============================] - 1s 56ms/step - loss: 0.7036 - acc: 0.6950 - val_loss: 0.7166 - val_acc: 0.6800
# Epoch 4/100
# 10/10 [==============================] - 1s 56ms/step - loss: 0.7820 - acc: 0.6450 - val_loss: 0.7813 - val_acc: 0.7200
# Epoch 5/100
# 10/10 [==============================] - 1s 56ms/step - loss: 0.8623 - acc: 0.6000 - val_loss: 0.7344 - val_acc: 0.6800
# Epoch 6/100
# 10/10 [==============================] - 1s 57ms/step - loss: 0.8696 - acc: 0.6200 - val_loss: 0.6987 - val_acc: 0.6300
# Epoch 7/100
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6551 - acc: 0.7250 - val_loss: 0.6858 - val_acc: 0.6800
# Epoch 8/100
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='categorical')

test_loss, test_acc = model.evaluate_generator(test_generator, steps=50)
print('test acc:', test_acc)
# Out:
# Found 200 images belonging to 4 classes.
# test acc: 0.66
